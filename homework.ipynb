# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movie.describe(include=['float64']).T
# Out:
#                           count          mean           std      min  \
# num_critic_for_reviews   4867.0  1.379889e+02  1.202394e+02     1.00
# duration                 4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes  4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes   4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes   4909.0  6.494488e+03  1.510699e+04     0.00
# gross                    4054.0  4.764451e+07  6.737255e+07   162.00
# facenumber_in_poster     4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews     4895.0  2.676688e+02  3.729348e+02     1.00
# budget                   4432.0  3.654749e+07  1.002427e+08   218.00
# title_year               4810.0  2.002448e+03  1.245398e+01  1916.00
# actor_2_facebook_likes   4903.0  1.621924e+03  4.011300e+03     0.00
# imdb_score               4916.0  6.437429e+00  1.127802e+00     1.60
# aspect_ratio             4590.0  2.222349e+00  1.402940e+00     1.18
#
# ...

# %%
movie = pd.read_csv('data/movie.csv')
m2 = [
    'num_critic_for_reviews',
    'duration',
    'director_facebook_likes',
    'actor_3_facebook_likes',
    'actor_1_facebook_likes',
    'gross',
    'facenumber_in_poster',
    'num_user_for_reviews',
    'budget',
    'title_year',
    'actor_2_facebook_likes',
    'imdb_score',
    'aspect_ratio'
]
m2 = movie.iloc[:, :11].fillna(0)
m2.head().T
# Out:
#                                                        0  \
# color                                              Color
# director_name                              James Cameron
# num_critic_for_reviews                             723.0
# duration                                           178.0
# director_facebook_likes                              0.0
# actor_3_facebook_likes                             855.0
# actor_2_name                            Joel David Moore
# actor_1_facebook_likes                            1000.0
# gross                                        760505847.0
# genres                   Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                 CCH Pounder
#
#                                                 1                          2  \
# color                                       Color                      Color
# director_name                      Gore Verbinski                 Sam Mendes
# ...

# %%
m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   color                    4916 non-null   object
#  1   director_name            4916 non-null   object
#  2   num_critic_for_reviews   4916 non-null   float64
#  3   duration                 4916 non-null   float64
#  4   director_facebook_likes  4916 non-null   float64
#  5   actor_3_facebook_likes   4916 non-null   float64
#  6   actor_2_name             4916 non-null   object
#  7   actor_1_facebook_likes   4916 non-null   float64
#  8   gross                    4916 non-null   float64
#  9   genres                   4916 non-null   object
#  10  actor_1_name             4916 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 422.6+ KB

# %%
m2.memory_usage(deep=True)
# Out:
# Index                         128
# color                      306262
# director_name              343388
# num_critic_for_reviews      39328
# duration                    39328
# director_facebook_likes     39328
# actor_3_facebook_likes      39328
# actor_2_name               346635
# actor_1_facebook_likes      39328
# gross                       39328
# genres                     379929
# actor_1_name               346599
# dtype: int64

# %%
np.finfo('float32')
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
m2['num_critic_for_reviews'] = m2['num_critic_for_reviews'].astype(np.float16)
m2['duration'] = m2['duration'].astype(np.float16)
m2['director_facebook_likes'] = m2['director_facebook_likes'].astype(np.float16)
m2['actor_3_facebook_likes'] = m2['actor_3_facebook_likes'].astype(np.float16)
m2['actor_1_facebook_likes'] = m2['actor_1_facebook_likes'].astype(np.float16)
m2['gross'] = m2['gross'].astype(np.float16)

# %%
m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   color                    4916 non-null   object
#  1   director_name            4916 non-null   object
#  2   num_critic_for_reviews   4916 non-null   float16
#  3   duration                 4916 non-null   float16
#  4   director_facebook_likes  4916 non-null   float16
#  5   actor_3_facebook_likes   4916 non-null   float16
#  6   actor_2_name             4916 non-null   object
#  7   actor_1_facebook_likes   4916 non-null   float16
#  8   gross                    4916 non-null   float16
#  9   genres                   4916 non-null   object
#  10  actor_1_name             4916 non-null   object
# dtypes: float16(6), object(5)
# memory usage: 249.8+ KB

# %%
college = pd.read_csv('data/college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   INSTNM              7535 non-null   object
#  1   CITY                7535 non-null   object
#  2   STABBR              7535 non-null   object
#  3   HBCU                7164 non-null   float64
#  4   MENONLY             7164 non-null   float64
#  5   WOMENONLY           7164 non-null   float64
#  6   RELAFFIL            7535 non-null   int64
#  7   SATVRMID            1185 non-null   float64
#  8   SATMTMID            1196 non-null   float64
#  9   DISTANCEONLY        7164 non-null   float64
#  10  UGDS                6874 non-null   float64
#  11  UGDS_WHITE          6874 non-null   float64
#  12  UGDS_BLACK          6874 non-null   float64
#  13  UGDS_HISP           6874 non-null   float64
#  14  UGDS_ASIAN          6874 non-null   float64
# ...

# %%
(
    college[['INSTNM','CITY','UGDS']]
    .nlargest(100, 'UGDS')
)
# Out:
#                                           INSTNM           CITY      UGDS
# 7116               University of Phoenix-Arizona          Tempe  151558.0
# 1189                  Ivy Tech Community College   Indianapolis   77657.0
# 793                           Miami Dade College          Miami   61470.0
# 3711                    Lone Star College System  The Woodlands   59920.0
# 3669                   Houston Community College        Houston   58084.0
# ...                                          ...            ...       ...
# 107                  Northern Arizona University      Flagstaff   23189.0
# 916                    Kennesaw State University       Kennesaw   23058.0
# 332                            Fullerton College      Fullerton   22990.0
# 2726  North Carolina State University at Raleigh        Raleigh   22925.0
# 3107                     Oregon State University      Corvallis   22925.0
#
# [100 rows x 3 columns]

# %%
(
    college[['INSTNM','RELAFFIL','UGDS','STABBR']]
    .nlargest(100, 'RELAFFIL')
    .nlargest(100, 'UGDS')
)
# Out:
#                                  INSTNM  RELAFFIL    UGDS STABBR
# 493         University of San Francisco         1  6745.0     CA
# 223       California Baptist University         1  6435.0     CA
# 274                  Chapman University         1  6211.0     CA
# 391         Loyola Marymount University         1  6064.0     CA
# 210            Azusa Pacific University         1  5918.0     CA
# ..                                  ...       ...     ...    ...
# 517                  Trinity Law School         1     NaN     CA
# 532  Starr King School for the Ministry         1     NaN     CA
# 538        Claremont School of Theology         1     NaN     CA
# 592                     Denver Seminary         1     NaN     CO
# 600            Iliff School of Theology         1     NaN     CO
#
# [100 rows x 4 columns]

# %%
(
    college[['INSTNM','RELAFFIL','UGDS','STABBR']]
   .sort_values(['UGDS'],
                ascending=[False])
    .drop_duplicates(subset=['STABBR','RELAFFIL'])
    
)
# Out:
#                                                 INSTNM  RELAFFIL      UGDS  \
# 7116                     University of Phoenix-Arizona         0  151558.0
# 1189                        Ivy Tech Community College         0   77657.0
# 793                                 Miami Dade College         0   61470.0
# 3711                          Lone Star College System         0   59920.0
# 3880                                Liberty University         1   49340.0
# ...                                                ...       ...       ...
# 64                           Alaska Pacific University         1     275.0
# 5289                        Pacific Islands University         1      65.0
# 6439                           Touro University Nevada         1      31.0
# 7404  University of the Virgin Islands-Albert A. Sheen         1       NaN
# 7419                 Computer Career Center-Las Cruces         1       NaN
#
#      STABBR
# 7116     AZ
# 1189     IN
# 793      FL
# 3711     TX
# ...
